# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd 
import numpy as np
# %matplotlib inline
from numpy.random import randn, randint, sample, uniform

# %%
x= [1, 2, 3, 4, 5, 6,7, 8, 9]
y1=[1,3, 5, 3, 1, 3, 5, 3,1]
y2=[2,4,6,4,2,4,6,4,2]

# %%
plt.plot(x,y1,label="Line L")
plt.plot(x,y2, label="Line H")
plt.plot()

plt.xlabel("x axis")
plt.ylabel(" y axis")
plt.title("Line graph example")
plt.legend()
plt.show()

# %%
x1=[1, 3, 4, 5, 6, 7, 9]
y1=[4,7,2,4,7,8,3]
x2=[2,4,6,8,10]
y2=[5,6,2,6,2]

# %%
plt.bar(x1, y1, label="Blue Bar", color="b")
plt.bar(x2,y2, label="Green Bar", color='g')
plt.plot()
plt.xlabel("bar number")
plt.ylabel("bar chart example")
plt.legend()
plt.show()

# %%
a = np.array([22,87,5,.43,56,73,55,54,11,20,51,5,79,31,27,9])
plt.hist(a)
plt.title("histogram")
plt.show()

# %%
iris=sns.load_dataset('iris')
iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
iris["sepal_length"].plot.hist()

# %%
iris.plot.hist()

# %%
iris.plot(kind="hist", stacked=True, bins=20)

# %%
iris.plot(kind="hist", stacked=False, bins=20)

# %%
df=iris.drop(["species"], axis=1)

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
df.hist(color= "#FF33F4", alpha= 0.3 ,figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f025dbd2190>,
# ...
#       dtype=object)

# %%
labels=['Python', 'c++', 'ruby', 'java']
size=[215,130,245,210]
explode=(0.4,0,0,0)
colors= ['gold','yellowgreen','lightcoral','lightskyblue']
plt.pie(size,explode=explode,labels=labels,colors=colors, autopct="%1.2f%%", shadow=False)
plt.axis("equal")
plt.show()
